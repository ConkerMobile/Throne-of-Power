# %%
import Player
import importlib
from IPython.display import clear_output

# %%
importlib.reload(Player)
# Out:
# <module 'Player' from 'C:\\Users\\qingy\\Documents\\Throne-of-Power\\Player.py'>

# %%
import sys
sys.modules.pop('Player')
# Out:
# <module 'Player' from 'C:\\Users\\qingy\\Documents\\Throne-of-Power\\Player.py'>

# %%
def SaveAccount(player):
    Saved_Accounts = open("Saved Accounts.txt",mode='a')
    Saved_Accounts.write(f"{player.name} = Player.Player(name = '{player.name}', wins = {player.wins},health={player.health},moves={player.moves},damage = {player.damage},max_damage={player.max_damage}, dragons={player.dragons})\n")
    Saved_Accounts.close()

# %% [markdown]
# # Bot Battles

# %%
Bot = Player.Player("Bot Pupy")

# %%
Bot.damage
# Out:
# {'Electric Bolt': 170, 'Super Nova': 250}

# %% [markdown]
# # Test Battles

# %%
Test = Player.Player("Froggie")

# %%
Test.max_damage
# Out:
# 0

# %%
Test.moves
# Out:
# ['Electric Bolt', 'Super Nova']

# %% [markdown]
# # Creating Station

# %% [markdown]
# # Dragons

# %% [markdown]
# In order to get a dragon, first finish a maze: maze.svg

# %%
import Player
Shadow = Player.Player(name = 'Shadow')
Koala = Player.Player(name = 'Koala')
Cat = Player.Player(name = 'White Cat')

# %%
Shadow = Player.Player(name = 'Shadow')

# %%
print(Shadow.dragons[0]) #OMG!
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-1b6a33c6dc88> in <module>
# ----> 1 print(Shadow.dragons[0]) #OMG!
#
# IndexError: list index out of range

# %%
print(Koala.dragons[0])

# %%
Stealth = Shadow.dragons[0]

# %%
Stealth.upgrade()

# %%
Test = Player.Player(name = "Test")

# %% [markdown]
# # Create Status

# %%
Shadow.complete_maze()

# %%
Koala.complete_maze()

# %%
Cat.complete_maze()

# %%
Shadow.moves

# %%
Koala.damage

# %%
Cat.moves

# %%
Cat.max_damage

# %%
Shadow.max_damage
# Out:
# 0

# %%
Shadow.moves

# %%
Shadow.battle_health

# %%
Test.battle_health

# %%
from tkinter import messagebox
def Battle(Player1, Player2):
    if messagebox.askquestion("Battle", "⚔ Are you ready? ⚔"):
        messagebox.ABORT()
        Player1.battle_health = Player1.health
        Player2.battle_health = Player2.health
        current_player = 1
        while (True):
            clear_output(wait=True)
            print(f"""
            {Player1.name}                                                       {Player2.name}
           {Player1.damage}           {Player2.damage} 
              Health: {Player1.battle_health}                                                   Health: {Player2.battle_health}
              Total Damage: {Player1.max_damage}                                         Total Damage: {Player2.max_damage}
              """)
            if (Player1.battle_health <= 0):
                print(f"{Player2.name} WINS!!!!")
                Player2.wins+=1
                break
            if (Player2.battle_health <= 0):
                print(f"{Player1.name} WINS!!!!")
                Player1.wins+=1
                break
            if (current_player == 1):
                input_move = str(input(f"{Player1.name}| Which move do you choose: "))
                if (input_move in Player1.moves):
                    Player2.battle_health-= Player1.damage[input_move]
                    current_player = 2
                    continue
            elif (current_player == 2):
                input_move = str(input(f"{Player2.name}| Which move do you choose: "))
                if (input_move in Player2.moves):
                    Player1.battle_health-= Player2.damage[input_move]
                    current_player = 1
                    continue

# %%
print(Shadow.dragons[0].toPlayer(),Cat)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-715dc26a90b7> in <module>
# ----> 1 print(Shadow.dragons[0].toPlayer(),Cat)
#
# IndexError: list index out of range

# %% [markdown]
# # Public Battle Station

# %%
Battle(Koala,Shadow)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5c5ccb4c8042> in <module>
# ----> 1 Battle(Koala,Shadow)
#
# <ipython-input-3-b128f4f43d31> in Battle(Player1, Player2)
#       2 def Battle(Player1, Player2):
#       3     if messagebox.askquestion("Battle", "⚔ Are you ready? ⚔"):
# ----> 4         tkinter.destroy()
#       5         Player1.battle_health = Player1.health
#       6         Player2.battle_health = Player2.health
#
# NameError: name 'tkinter' is not defined

# %% [markdown]
# # Wins

# %%
Shadow.wins

# %%
Cat.wins

# %%
Test.wins

# %%
Koala.wins

# %%
Koala.dragons[0].toPlayer().wins

# %% [markdown]
# # Upgrades

# %%
Shadow.upgrade()

# %%
Shadow.dragons[0].upgrade()

# %%
Koala.dragons[0].upgrade()

# %%
Shadow.damage

# %%
Koala.dragons[0].damage

# %%
Cat.upgrade()

# %%
Koala.upgrade()

# %%
Cat.health

# %%
Shadow.health

# %%
Shadow.damage

# %%
Koala.health

# %%
Koala.damage

# %%
Cat.damage
